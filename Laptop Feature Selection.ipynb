# %%
""""
MAULANA MUHAMMAD
DATA SET : https://www.kaggle.com/datasets/deepann/4000-laptops-data-from-gadgets360?select=laptops.csv
"""

# %%
import pandas as pd

df = pd.read_csv("laptops.csv")
df.head()
# Out:
#                                                 link     Brand  \
# 0  https://gadgets.ndtv.com/micromax-in-note-1-pr...  Micromax
# 1  https://gadgets.ndtv.com/hp-pavilion-15-ab205t...        HP
# 2  https://gadgets.ndtv.com/hp-pavilion-15-au626t...        HP
# 3   https://gadgets.ndtv.com/asus-r558uq-dm539d-5335      Asus
# 4            https://gadgets.ndtv.com/hp-240-g4-5066        HP
#
#                  Model   Company  \
# 0            In Note 1  micromax
# 1  Pavilion 15-ab205tx        hp
# 2  Pavilion 15-AU626TX        hp
# 3        R558UQ-DM539D      asus
# 4               240 G4        hp
#
#                                              picture Price in India  1 stars  \
# 0  https://i.gadgets360cdn.com/products/large/mic...       ₹ 10,999        5
# 1  https://i.gadgets360cdn.com/products/laptops/l...       ₹ 49,790        9
# 2  https://i.gadgets360cdn.com/products/laptops/l...       ₹ 69,980       21
# ...

# %%
df.drop(columns=["total_ratings","1 stars","2 stars","3 stars","link","Price in India","Touchpad","Pointer Device","Cache","Mic In","Product Name","Model","Company","picture","Speakers", "RJ45 (LAN)", "Dedicated Graphics.1", "HDMI Port", "Ethernet", "Battery Life (up to hours)", "Dedicated Graphic Memory Type","Operating system","Hard disk","Model Number","Processor","Graphics Processor","Dedicated Graphics","Finger Print Sensor","Resolution","Wi-Fi standards supported","Weight (kg)","Dimensions (mm)","Bluetooth version","Number of USB Ports","Series","Internal Mic","Touch Screen","Base Clock Speed","Graphics Processor","Product Name","Touchpad","Battery Cell","Pointer Device","USB Ports","Cache","Mic In","Speakers","Multi Card Slot","RJ45 (LAN)","Dedicated Graphics","HDMI Port","Ethernet","Battery Life (up to hours)","Dedicated Graphic Memory Type","Expandable RAM up to (GB)","other_info"], inplace=True)
df.dropna(inplace=True)
df
# Out:
#           Brand  4 stars  5 stars   RAM        Size    SSD            Colours  \
# 1            HP       45       45   4GB  15.60-inch     No     Natural Silver
# 2            HP       17       45  16GB  15.60-inch     No             Silver
# 3          Asus       37       37   4GB  15.60-inch     No  Glossy Dark Brown
# 4            HP        9       41   4GB  14.00-inch     No              Black
# 6          Acer       25       25   4GB  15.60-inch     No              Black
# ...         ...      ...      ...   ...         ...    ...                ...
# 4414  Alienware        0        0   8GB  15.60-inch     No              Black
# 4429         HP        0        0   4GB  14.00-inch     No             Silver
# 4440  Alienware        0        0   8GB  15.60-inch     No              Black
# 4485        MSI        0        0   8GB  17.30-inch  128GB              Black
# 4777       Dell        0        0   8GB  15.60-inch  512GB              Black
#
#          Graphics Processor.1
# ...

# %%
df["Good"] = ((df["4 stars"]+df["5 stars"]).apply(lambda x: 1 if x>50 else 0))
df
# Out:
#           Brand  4 stars  5 stars   RAM        Size    SSD            Colours  \
# 1            HP       45       45   4GB  15.60-inch     No     Natural Silver
# 2            HP       17       45  16GB  15.60-inch     No             Silver
# 3          Asus       37       37   4GB  15.60-inch     No  Glossy Dark Brown
# 4            HP        9       41   4GB  14.00-inch     No              Black
# 6          Acer       25       25   4GB  15.60-inch     No              Black
# ...         ...      ...      ...   ...         ...    ...                ...
# 4414  Alienware        0        0   8GB  15.60-inch     No              Black
# 4429         HP        0        0   4GB  14.00-inch     No             Silver
# 4440  Alienware        0        0   8GB  15.60-inch     No              Black
# 4485        MSI        0        0   8GB  17.30-inch  128GB              Black
# 4777       Dell        0        0   8GB  15.60-inch  512GB              Black
#
# ...

# %%
import seaborn as sns
sns.barplot(x="Brand", y="4 stars", data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='4 stars'>

# %%
sns.barplot(x='SSD', y='5 stars', data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='SSD', ylabel='5 stars'>

# %%
ax = sns.barplot(x='Good', y='4 stars', data=df, ci=None)    
ax.set_xticklabels(['Not Good','Good'])
# Out:
# [Text(0, 0, 'Not Good'), Text(1, 0, 'Good')]

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(df["Brand"])
df["Brand"] = le.transform(df["Brand"])
brand_labels = dict(zip(le.classes_, le.transform(le.classes_)))
print(brand_labels)
# Out:
# {'AGB': 0, 'Acer': 1, 'Alienware': 2, 'Apple': 3, 'Asus': 4, 'Dell': 5, 'Fujitsu': 6, 'HP': 7, 'Honor': 8, 'Huawei': 9, 'LG': 10, 'Lava': 11, 'Lenovo': 12, 'MSI': 13, 'Micromax': 14, 'Microsoft': 15, 'RDP': 16, 'Razer': 17, 'Reach': 18, 'Samsung': 19, 'Toshiba': 20, 'Xiaomi': 21, 'iBall': 22, 'iLife': 23}

# %%
le.fit(df["RAM"])
df["RAM"]=le.transform(df["RAM"])
ram_labels=dict(zip(le.classes_, le.transform(le.classes_)))
print(ram_labels)
# Out:
# {'12GB': 0, '16GB': 1, '1GB': 2, '24GB': 3, '2GB': 4, '32GB': 5, '3GB': 6, '4GB': 7, '6GB': 8, '8GB': 9}

# %%
le.fit(df["Size"])
df["Size"]=le.transform(df["Size"])
ram_labels=dict(zip(le.classes_, le.transform(le.classes_)))
print(ram_labels)
# Out:
# {'10.00-inch': 0, '10.10-inch': 1, '11.00-inch': 2, '11.06-inch': 3, '11.49-inch': 4, '11.60-inch': 5, '11.78-inch': 6, '12.00-inch': 7, '12.30-inch': 8, '12.38-inch': 9, '12.50-inch': 10, '13.00-inch': 11, '13.17-inch': 12, '13.30-inch': 13, '13.40-inch': 14, '13.50-inch': 15, '13.86-inch': 16, '13.90-inch': 17, '14.00-inch': 18, '14.10-inch': 19, '15.00-inch': 20, '15.40-inch': 21, '15.50-inch': 22, '15.59-inch': 23, '15.60-inch': 24, '15.84-inch': 25, '16.00-inch': 26, '16.10-inch': 27, '17.00-inch': 28, '17.30-inch': 29, '18.40-inch': 30, '23.80-inch': 31, '27.00-inch': 32}

# %%
le.fit(df["SSD"])
df["SSD"]=le.transform(df["SSD"])
ssd_labels=dict(zip(le.classes_, le.transform(le.classes_)))
print(ssd_labels)
# Out:
# {'128GB': 0, '16GB': 1, '180GB': 2, '1TB': 3, '240GB': 4, '24GB': 5, '256GB': 6, '32GB': 7, '360GB': 8, '480GB': 9, '512GB': 10, '64GB': 11, '8GB': 12, 'No': 13}

# %%
le.fit(df["Colours"])
df["Colours"]=le.transform(df["Colours"])
colours_labels=dict(zip(le.classes_, le.transform(le.classes_)))
print(colours_labels)
# Out:
# {'Abyss Black': 0, 'Abyss Grey': 1, 'Alpine White, Eclipse Black': 2, 'Aluminium': 3, 'Aluminium Finish Natural Silver': 4, 'Aluminum Black': 5, 'Anodized Aluminum': 6, 'Aqua Blue': 7, 'Black': 8, 'Black Aluminum': 9, 'Black Glossy': 10, 'Black Metal': 11, 'Black Texture': 12, 'Black With Red Accents': 13, 'Black With Straight Hair Line Texture': 14, 'Black, Blue': 15, 'Black, Silver': 16, 'Black, Silver, Blue': 17, 'Black, White': 18, 'Blizzard White': 19, 'Blue': 20, 'Blue Grey With Diamond Texture': 21, 'Blue Metal': 22, 'Blue, Silver': 23, 'Blue, White': 24, 'Bonfire Black, Fortress Gray': 25, 'Brilliant Red': 26, 'Brilliant Red, Silver': 27, 'Bronze': 28, 'Brown': 29, 'Burgundy': 30, 'Carbon Gray': 31, 'Cardinal Red': 32, 'Celestial Blue': 33, 'Ceramic White': 34, 'Champagne': 35, 'Charcoal': 36, 'Charcoal Black': 37, 'Charcoal Blue': 38, 'Charcoal Grey': 39, 'Chocolate Black': 40, 'Chocolate Black Imr With Hairline': 41, 'Chocolate Black With Hairline Texture': 42, 'Cobalt': 43
# ...

# %%
le.fit(df["Graphics Processor.1"])
df["Graphics Processor.1"]=le.transform(df["Graphics Processor.1"])
graphics_labels=dict(zip(le.classes_, le.transform(le.classes_)))
print(graphics_labels)
# Out:
# {'AMD R5 M230': 0, 'AMD Radeon 315M': 1, 'AMD Radeon 315M Graphics': 2, 'AMD Radeon 450 Graphics': 3, 'AMD Radeon 455 Graphics': 4, 'AMD Radeon 520 Graphics': 5, 'AMD Radeon 530 Graphics': 6, 'AMD Radeon 6480G': 7, 'AMD Radeon 8240 Graphics': 8, 'AMD Radeon 8400 Graphics': 9, 'AMD Radeon 8750M': 10, 'AMD Radeon Exo Pro R5 M330': 11, 'AMD Radeon HD 8330 Graphics': 12, 'AMD Radeon HD 8400 Graphics': 13, 'AMD Radeon HD 8670M': 14, 'AMD Radeon Integrated Graphics': 15, 'AMD Radeon Integrated R2 Graphics': 16, 'AMD Radeon Jet Le R5 M230': 17, 'AMD Radeon Jet Le R5 M330': 18, 'AMD Radeon M330': 19, 'AMD Radeon M420': 20, 'AMD Radeon Meso Xt': 21, 'AMD Radeon R16M M1 30': 22, 'AMD Radeon R2': 23, 'AMD Radeon R4': 24, 'AMD Radeon R5': 25, 'AMD Radeon R5 M230': 26, 'AMD Radeon R5 M330': 27, 'AMD Radeon R5 M335': 28, 'AMD Radeon R5 M430': 29, 'AMD Radeon R6 M345DX': 30, 'AMD Radeon R7 M265': 31, 'AMD Radeon R7 M270': 32, 'AMD Radeon R7 M360': 33, 'AMD Radeon R7 M440': 34, 'AMD Radeon RX 580': 
# ...

# %%
df
# Out:
#       Brand  4 stars  5 stars  RAM  Size  SSD  Colours  Graphics Processor.1  \
# 1         7       45       45    7    24   13      135                    28
# 2         7       17       45    1    24   13      167                   121
# 3         4       37       37    7    24   13       70                   121
# 4         7        9       41    7    18   13        8                    27
# 6         1       25       25    7    24   13        8                    10
# ...     ...      ...      ...  ...   ...  ...      ...                   ...
# 4414      2        0        0    9    24   13        8                   137
# 4429      7        0        0    7    18   13      167                   102
# 4440      2        0        0    9    24   13        8                   137
# 4485     13        0        0    9    29    0        8                   123
# 4777      5        0        0    9    24   10        8                   105
#
#       Good
# 1        1
# 2        1
# ...

# %%
#X = Featurs ; Y = Class
X=df.iloc[:,1:]
X
# Out:
#       4 stars  5 stars  RAM  Size  SSD  Colours  Graphics Processor.1  Good
# 1          45       45    7    24   13      135                    28     1
# 2          17       45    1    24   13      167                   121     1
# 3          37       37    7    24   13       70                   121     1
# 4           9       41    7    18   13        8                    27     0
# 6          25       25    7    24   13        8                    10     0
# ...       ...      ...  ...   ...  ...      ...                   ...   ...
# 4414        0        0    9    24   13        8                   137     0
# 4429        0        0    7    18   13      167                   102     0
# 4440        0        0    9    24   13        8                   137     0
# 4485        0        0    9    29    0        8                   123     0
# 4777        0        0    9    24   10        8                   105     0
#
# [3182 rows x 8 columns]

# %%
Y = df.iloc[:,0]
Y
# Out:
# 1        7
# 2        7
# 3        4
# 4        7
# 6        1
#         ..
# 4414     2
# 4429     7
# 4440     2
# 4485    13
# 4777     5
# Name: Brand, Length: 3182, dtype: int32

# %%
# Metode Filter -> Chi Square
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestfeatures = SelectKBest(score_func=chi2, k=4)
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

featureScore = pd.concat([dfcolumns, dfscores], axis=1)
featureScore.columns = ['Attr', 'Score']
print(featureScore.nlargest(4,'Score'))
# Out:
#                    Attr         Score
# 5               Colours  41448.713994
# 6  Graphics Processor.1   5386.756464
# 1               5 stars   2996.697071
# 0               4 stars    959.748687

# %%
#Metode Wrapp -> RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
rfe = RFE(model)
fit = rfe.fit(X,Y)

print("Num Features: %s" %(fit.n_features_))
print("Selected Features: %s" %(fit.support_))
print("Feature Ranking: %s" %(fit.ranking_))

dfscores = pd.DataFrame(fit.support_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns, dfscores], axis=1)
featureScores.columns=["Attr", "Score"]
print(featureScores.nlargest(7,'Score'))
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Feature Selection metode Embbeded
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)
ridge.fit(X,Y)
print(ridge.coef_)

def pretty_print_coefs(coefs, names = None, sort = False):
    if names == None:
        names = ["X-%s" % x for x in X.columns]
    print(names)
    lst = zip(coefs, names)
    if sort:
        lst = sorted(lst,  key = lambda x:-np.abs(x[0]))
    return " + ".join("%s * %s" % (round(coef, 3), name)
                                   for coef, name in lst)

print ("Ridge model:", pretty_print_coefs(ridge.coef_))
# Out:
# [-0.00273876  0.00797405 -0.16310335 -0.01615991 -0.08415854  0.00132831
#  -0.00327906  0.02555554]
# ['X-4 stars', 'X-5 stars', 'X-RAM', 'X-Size', 'X-SSD', 'X-Colours', 'X-Graphics Processor.1', 'X-Good']
# Ridge model: -0.003 * X-4 stars + 0.008 * X-5 stars + -0.163 * X-RAM + -0.016 * X-Size + -0.084 * X-SSD + 0.001 * X-Colours + -0.003 * X-Graphics Processor.1 + 0.026 * X-Good

# %%
"""
Pada Ridge regression akan menghasilkan bobot untuk tiap attribute.
"""
# Out:
# '\nPada Ridge regression akan menghasilkan bobot untuk tiap attribute.\n'
